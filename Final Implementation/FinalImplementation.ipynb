# %% [markdown]
# #SECURE FEDERATED LEARNING FOR AI

# %%
# !pip install syft==0.2.9
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting syft==0.2.9
#   Downloading syft-0.2.9-py3-none-any.whl (433 kB)
#      |████████████████████████████████| 433 kB 4.9 MB/s
# Collecting websockets~=8.1.0
#   Downloading websockets-8.1-cp38-cp38-manylinux2010_x86_64.whl (78 kB)
#      |████████████████████████████████| 78 kB 2.6 MB/s
# Collecting scipy~=1.4.1
#   Downloading scipy-1.4.1-cp38-cp38-manylinux1_x86_64.whl (26.0 MB)
#      |████████████████████████████████| 26.0 MB 1.6 MB/s
# Requirement already satisfied: Pillow>=7.1.0 in /usr/local/lib/python3.8/dist-packages (from syft==0.2.9) (7.1.2)
# Collecting openmined.threepio==0.2.0
#   Downloading openmined.threepio-0.2.0.tar.gz (73 kB)
#      |████████████████████████████████| 73 kB 1.1 MB/s
# Collecting tornado==4.5.3
#   Downloading tornado-4.5.3.tar.gz (484 kB)
#      |████████████████████████████████| 484 kB 6.1 MB/s
# Collecting lz4~=3.0.2
#   Downloading lz4-3.0.2-cp38-cp38-manylinux2010_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 47.9 MB/s
# Collecting shaloop==0.2.1-alpha.11
#   Downloading shaloop-0.2.1_alpha.11-py3-none-manylinux1_x86_64.whl (126 kB)
#      |████████████████████████████████| 126 kB 17.1 MB/s
# Collecting psutil==5.7.0
#   Downloading psutil-5.7.0.tar.gz (449 kB)
#      |████████████████████████████████| 449 kB 38.4 MB/s
# Collecting aiortc==0.9.28
#   Downloading aiortc-0.9.28-cp38-cp38-manylinux2010_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 43.1 MB/s
# Collecting notebook==5.7.8
#   Downloading notebook-5.7.8-py2.py3-none-any.whl (9.0 MB)
#      |████████████████████████████████| 9.0 MB 26.7 MB/s
# Collecting torchvision~=0.5.0
#   Downloading torchvision-0.5.0-cp38-cp38-manylinux1_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 30.9 MB/s
# Collecting RestrictedPython~=5.0
#   Downloading RestrictedPython-5.2-py2.py3-none-any.whl (28 kB)
# Collecting tblib~=1.6.0
#   Downloading tblib-1.6.0-py2.py3-none-any.whl (12 kB)
# Collecting flask-socketio~=4.2.1
#   Downloading Flask_SocketIO-4.2.1-py2.py3-none-any.whl (16 kB)
# Collecting torch~=1.4.0
#   Downloading torch-1.4.0-cp38-cp38-manylinux1_x86_64.whl (753.4 MB)
#      |████████████████████████████████| 753.4 MB 19 kB/s
# Collecting requests~=2.22.0
#   Downloading requests-2.22.0-py2.py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 6.2 MB/s
# Collecting websocket-client~=0.57.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
#      |████████████████████████████████| 200 kB 63.1 MB/s
# Requirement already satisfied: Flask~=1.1.1 in /usr/local/lib/python3.8/dist-packages (from syft==0.2.9) (1.1.4)
# Collecting syft-proto~=0.5.2
#   Downloading syft_proto-0.5.3-py3-none-any.whl (66 kB)
#      |████████████████████████████████| 66 kB 4.4 MB/s
# Requirement already satisfied: dill~=0.3.1 in /usr/local/lib/python3.8/dist-packages (from syft==0.2.9) (0.3.6)
# Requirement already satisfied: msgpack~=1.0.0 in /usr/local/lib/python3.8/dist-packages (from syft==0.2.9) (1.0.4)
# Collecting phe~=1.4.0
#   Downloading phe-1.4.0.tar.gz (35 kB)
# Collecting importlib-resources~=1.5.0
#   Downloading importlib_resources-1.5.0-py2.py3-none-any.whl (21 kB)
# Collecting requests-toolbelt==0.9.1
#   Downloading requests_toolbelt-0.9.1-py2.py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 3.0 MB/s
# Collecting numpy~=1.18.1
#   Downloading numpy-1.18.5-cp38-cp38-manylinux1_x86_64.whl (20.6 MB)
#      |████████████████████████████████| 20.6 MB 9.0 MB/s
# Collecting crc32c
#   Downloading crc32c-2.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43 kB)
#      |████████████████████████████████| 43 kB 1.9 MB/s
# Collecting pyee>=6.0.0
#   Downloading pyee-9.0.4-py2.py3-none-any.whl (14 kB)
# Collecting pylibsrtp>=0.5.6
#   Downloading pylibsrtp-0.7.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (71 kB)
#      |████████████████████████████████| 71 kB 9.1 MB/s
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from aiortc==0.9.28->syft==0.2.9) (1.15.1)
# Collecting aioice<0.7.0,>=0.6.17
#   Downloading aioice-0.6.18-py3-none-any.whl (19 kB)
# Collecting cryptography>=2.2
#   Downloading cryptography-38.0.4-cp36-abi3-manylinux_2_24_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 45.3 MB/s
# Collecting av<9.0.0,>=8.0.0
#   Downloading av-8.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.7 MB)
#      |████████████████████████████████| 36.7 MB 376 kB/s
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.8/dist-packages (from notebook==5.7.8->syft==0.2.9) (5.3.4)
# Requirement already satisfied: jupyter-client>=5.2.0 in /usr/local/lib/python3.8/dist-packages (from notebook==5.7.8->syft==0.2.9) (6.1.12)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from notebook==5.7.8->syft==0.2.9) (0.13.3)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.8/dist-packages (from notebook==5.7.8->syft==0.2.9) (0.15.0)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.8/dist-packages (from notebook==5.7.8->syft==0.2.9) (4.11.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from notebook==5.7.8->syft==0.2.9) (2.11.3)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.8/dist-packages (from notebook==5.7.8->syft==0.2.9) (5.1.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.8/dist-packages (from notebook==5.7.8->syft==0.2.9) (5.6.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.8/dist-packages (from notebook==5.7.8->syft==0.2.9) (0.2.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.8/dist-packages (from notebook==5.7.8->syft==0.2.9) (23.2.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.8/dist-packages (from notebook==5.7.8->syft==0.2.9) (1.8.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.8/dist-packages (from notebook==5.7.8->syft==0.2.9) (5.7.0)
# Requirement already satisfied: pycparser>=2 in /usr/local/lib/python3.8/dist-packages (from shaloop==0.2.1-alpha.11->syft==0.2.9) (2.21)
# Collecting netifaces
#   Downloading netifaces-0.11.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (33 kB)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.8/dist-packages (from Flask~=1.1.1->syft==0.2.9) (1.0.1)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.8/dist-packages (from Flask~=1.1.1->syft==0.2.9) (7.1.2)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.8/dist-packages (from Flask~=1.1.1->syft==0.2.9) (1.1.0)
# Collecting python-socketio>=4.3.0
#   Downloading python_socketio-5.7.2-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 3.8 MB/s
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->notebook==5.7.8->syft==0.2.9) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.8/dist-packages (from jupyter-client>=5.2.0->notebook==5.7.8->syft==0.2.9) (2.8.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from pyee>=6.0.0->aiortc==0.9.28->syft==0.2.9) (4.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.1->jupyter-client>=5.2.0->notebook==5.7.8->syft==0.2.9) (1.15.0)
# Collecting python-engineio>=4.3.0
#   Downloading python_engineio-4.3.4-py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.3 MB/s
# Collecting bidict>=0.21.0
#   Downloading bidict-0.22.0-py3-none-any.whl (36 kB)
# Collecting idna<2.9,>=2.5
#   Downloading idna-2.8-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 5.6 MB/s
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests~=2.22.0->syft==0.2.9) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests~=2.22.0->syft==0.2.9) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests~=2.22.0->syft==0.2.9) (3.0.4)
# Requirement already satisfied: protobuf>=3.12.2 in /usr/local/lib/python3.8/dist-packages (from syft-proto~=0.5.2->syft==0.2.9) (3.19.6)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.8/dist-packages (from terminado>=0.8.1->notebook==5.7.8->syft==0.2.9) (0.7.0)
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.8/dist-packages (from ipykernel->notebook==5.7.8->syft==0.2.9) (7.9.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython>=5.0.0->ipykernel->notebook==5.7.8->syft==0.2.9) (0.7.5)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 71.1 MB/s
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython>=5.0.0->ipykernel->notebook==5.7.8->syft==0.2.9) (57.4.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython>=5.0.0->ipykernel->notebook==5.7.8->syft==0.2.9) (4.8.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython>=5.0.0->ipykernel->notebook==5.7.8->syft==0.2.9) (2.6.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython>=5.0.0->ipykernel->notebook==5.7.8->syft==0.2.9) (4.4.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython>=5.0.0->ipykernel->notebook==5.7.8->syft==0.2.9) (0.2.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython>=5.0.0->ipykernel->notebook==5.7.8->syft==0.2.9) (2.0.10)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel->notebook==5.7.8->syft==0.2.9) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->notebook==5.7.8->syft==0.2.9) (0.2.5)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert->notebook==5.7.8->syft==0.2.9) (1.5.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.8/dist-packages (from nbconvert->notebook==5.7.8->syft==0.2.9) (0.6.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from nbconvert->notebook==5.7.8->syft==0.2.9) (0.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.8/dist-packages (from nbconvert->notebook==5.7.8->syft==0.2.9) (5.0.1)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.8/dist-packages (from nbconvert->notebook==5.7.8->syft==0.2.9) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert->notebook==5.7.8->syft==0.2.9) (0.8.4)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook==5.7.8->syft==0.2.9) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook==5.7.8->syft==0.2.9) (4.3.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook==5.7.8->syft==0.2.9) (0.19.2)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook==5.7.8->syft==0.2.9) (22.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from bleach->nbconvert->notebook==5.7.8->syft==0.2.9) (0.5.1)
# Building wheels for collected packages: openmined.threepio, psutil, tornado, phe
#   Building wheel for openmined.threepio (setup.py) ... done
#   Created wheel for openmined.threepio: filename=openmined.threepio-0.2.0-py3-none-any.whl size=80095 sha256=9344f8859c6bdc0e828caad2bd5e4700c9cc0c9e27a4c04c6ef1b3a10f0c99b7
#   Stored in directory: /root/.cache/pip/wheels/79/4d/4f/ccec738f40c7a94fed7c0f1db1aecc944a8f0cdfe4f3867865
#   Building wheel for psutil (setup.py) ... done
#   Created wheel for psutil: filename=psutil-5.7.0-cp38-cp38-linux_x86_64.whl size=276900 sha256=19ddc1a7ae3a9a84e7f6b0f51ab0bfe01a550d0d86b5f486bced9f91a1f75e25
#   Stored in directory: /root/.cache/pip/wheels/90/c9/b6/04665702b01dbd9ee92a05e834b627948ed01cdd482e6a78e1
#   Building wheel for tornado (setup.py) ... done
#   Created wheel for tornado: filename=tornado-4.5.3-cp38-cp38-linux_x86_64.whl size=433027 sha256=cf6d5e82010dad91a7ee911e2ae60a9dcc81b2c1eec2a64c90d00e36b241ba0c
#   Stored in directory: /root/.cache/pip/wheels/20/fe/26/0c03adccd0cec2744261ec6b8380fbe5e726d1ea4cf3a9370e
#   Building wheel for phe (setup.py) ... done
#   Created wheel for phe: filename=phe-1.4.0-py2.py3-none-any.whl size=37362 sha256=3da1968c4bbbee728e4523608e53dd247dfe5540aa88e02d1aed05c8900358a3
#   Stored in directory: /root/.cache/pip/wheels/f7/6a/39/9f3220117feb615a398d60a0d6875f9becadee3d09af64f7bf
# Successfully built openmined.threepio psutil tornado phe
# Installing collected packages: importlib-resources, tornado, jedi, python-engineio, netifaces, idna, bidict, torch, requests, python-socketio, pylibsrtp, pyee, numpy, cryptography, crc32c, av, aioice, websockets, websocket-client, torchvision, tblib, syft-proto, shaloop, scipy, RestrictedPython, requests-toolbelt, psutil, phe, openmined.threepio, notebook, lz4, flask-socketio, aiortc, syft
#   Attempting uninstall: importlib-resources
#     Found existing installation: importlib-resources 5.10.0
#     Uninstalling importlib-resources-5.10.0:
#       Successfully uninstalled importlib-resources-5.10.0
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.0.4
#     Uninstalling tornado-6.0.4:
#       Successfully uninstalled tornado-6.0.4
#   Attempting uninstall: idna
#     Found existing installation: idna 2.10
#     Uninstalling idna-2.10:
#       Successfully uninstalled idna-2.10
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.1+cu113
#     Uninstalling torchvision-0.13.1+cu113:
#       Successfully uninstalled torchvision-0.13.1+cu113
#   Attempting uninstall: tblib
#     Found existing installation: tblib 1.7.0
#     Uninstalling tblib-1.7.0:
#       Successfully uninstalled tblib-1.7.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
#   Attempting uninstall: notebook
#     Found existing installation: notebook 5.7.16
#     Uninstalling notebook-5.7.16:
#       Successfully uninstalled notebook-5.7.16
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray-einstats 0.2.2 requires numpy>=1.21, but you have numpy 1.18.5 which is incompatible.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.4.0 which is incompatible.
# torchaudio 0.12.1+cu113 requires torch==1.12.1, but you have torch 1.4.0 which is incompatible.
# tensorflow 2.9.2 requires numpy>=1.20, but you have numpy 1.18.5 which is incompatible.
# tables 3.7.0 requires numpy>=1.19.0, but you have numpy 1.18.5 which is incompatible.
# plotnine 0.8.0 requires numpy>=1.19.0, but you have numpy 1.18.5 which is incompatible.
# plotnine 0.8.0 requires scipy>=1.5.0, but you have scipy 1.4.1 which is incompatible.
# jaxlib 0.3.25+cuda11.cudnn805 requires numpy>=1.20, but you have numpy 1.18.5 which is incompatible.
# jaxlib 0.3.25+cuda11.cudnn805 requires scipy>=1.5, but you have scipy 1.4.1 which is incompatible.
# jax 0.3.25 requires numpy>=1.20, but you have numpy 1.18.5 which is incompatible.
# jax 0.3.25 requires scipy>=1.5, but you have scipy 1.4.1 which is incompatible.
# google-colab 1.0.0 requires notebook~=5.7.16, but you have notebook 5.7.8 which is incompatible.
# google-colab 1.0.0 requires requests>=2.23.0, but you have requests 2.22.0 which is incompatible.
# google-colab 1.0.0 requires tornado~=6.0.4, but you have tornado 4.5.3 which is incompatible.
# fastai 2.7.10 requires torch<1.14,>=1.7, but you have torch 1.4.0 which is incompatible.
# fastai 2.7.10 requires torchvision>=0.8.2, but you have torchvision 0.5.0 which is incompatible.
# distributed 2022.2.0 requires tornado>=6.0.3; python_version >= "3.8", but you have tornado 4.5.3 which is incompatible.
# cmdstanpy 1.0.8 requires numpy>=1.21, but you have numpy 1.18.5 which is incompatible.
# bokeh 2.3.3 requires tornado>=5.1, but you have tornado 4.5.3 which is incompatible.
# Successfully installed RestrictedPython-5.2 aioice-0.6.18 aiortc-0.9.28 av-8.1.0 bidict-0.22.0 crc32c-2.3 cryptography-38.0.4 flask-socketio-4.2.1 idna-2.8 importlib-resources-1.5.0 jedi-0.18.2 lz4-3.0.2 netifaces-0.11.0 notebook-5.7.8 numpy-1.18.5 openmined.threepio-0.2.0 phe-1.4.0 psutil-5.7.0 pyee-9.0.4 pylibsrtp-0.7.1 python-engineio-4.3.4 python-socketio-5.7.2 requests-2.22.0 requests-toolbelt-0.9.1 scipy-1.4.1 shaloop-0.2.1a11 syft-0.2.9 syft-proto-0.5.3 tblib-1.6.0 torch-1.4.0 torchvision-0.5.0 tornado-4.5.3 websocket-client-0.57.0 websockets-8.1

# %%
# !pip install tensorflow-privacy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-privacy
#   Downloading tensorflow_privacy-0.8.7-py3-none-any.whl (301 kB)
#      |████████████████████████████████| 301 kB 4.8 MB/s
# Requirement already satisfied: tensorflow-datasets~=4.5 in /usr/local/lib/python3.8/dist-packages (from tensorflow-privacy) (4.6.0)
# Collecting tensorflow-probability==0.15.0
#   Downloading tensorflow_probability-0.15.0-py2.py3-none-any.whl (5.7 MB)
#      |████████████████████████████████| 5.7 MB 47.2 MB/s
# Requirement already satisfied: absl-py==1.*,>=1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-privacy) (1.3.0)
# Collecting pandas~=1.4
#   Downloading pandas-1.5.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      |████████████████████████████████| 12.2 MB 48.4 MB/s
# Requirement already satisfied: dm-tree==0.1.7 in /usr/local/lib/python3.8/dist-packages (from tensorflow-privacy) (0.1.7)
# Requirement already satisfied: tensorflow~=2.4 in /usr/local/lib/python3.8/dist-packages (from tensorflow-privacy) (2.9.2)
# Collecting matplotlib~=3.3
#   Downloading matplotlib-3.6.2-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.4 MB)
#      |████████████████████████████████| 9.4 MB 45.8 MB/s
# Collecting numpy~=1.21
#   Downloading numpy-1.23.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      |████████████████████████████████| 17.1 MB 36 kB/s
# Collecting dp-accounting==0.3.0
#   Downloading dp_accounting-0.3.0-py3-none-any.whl (89 kB)
#      |████████████████████████████████| 89 kB 5.2 MB/s
# Collecting scipy~=1.7
#   Downloading scipy-1.9.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.8 MB)
#      |████████████████████████████████| 33.8 MB 305 kB/s
# Requirement already satisfied: scikit-learn==1.*,>=1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-privacy) (1.0.2)
# Requirement already satisfied: tensorflow-estimator~=2.4 in /usr/local/lib/python3.8/dist-packages (from tensorflow-privacy) (2.9.0)
# Collecting attrs~=21.4
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 5.9 MB/s
# Requirement already satisfied: mpmath~=1.2.1 in /usr/local/lib/python3.8/dist-packages (from dp-accounting==0.3.0->tensorflow-privacy) (1.2.1)
# Collecting absl-py==1.*,>=1.0
#   Downloading absl_py-1.0.0-py3-none-any.whl (126 kB)
#      |████████████████████████████████| 126 kB 50.9 MB/s
# Collecting scipy~=1.7
#   Downloading scipy-1.7.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (39.3 MB)
#      |████████████████████████████████| 39.3 MB 1.4 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from absl-py==1.*,>=1.0->tensorflow-privacy) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn==1.*,>=1.0->tensorflow-privacy) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn==1.*,>=1.0->tensorflow-privacy) (3.1.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from tensorflow-probability==0.15.0->tensorflow-privacy) (4.4.2)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow-probability==0.15.0->tensorflow-privacy) (1.5.0)
# Requirement already satisfied: gast>=0.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow-probability==0.15.0->tensorflow-privacy) (0.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib~=3.3->tensorflow-privacy) (3.0.9)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (295 kB)
#      |████████████████████████████████| 295 kB 84.0 MB/s
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib~=3.3->tensorflow-privacy) (0.11.0)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      |████████████████████████████████| 965 kB 55.0 MB/s
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib~=3.3->tensorflow-privacy) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib~=3.3->tensorflow-privacy) (7.1.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib~=3.3->tensorflow-privacy) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib~=3.3->tensorflow-privacy) (21.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas~=1.4->tensorflow-privacy) (2022.6)
# Collecting numpy~=1.21
#   Downloading numpy-1.22.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.9 MB)
#      |████████████████████████████████| 16.9 MB 46.2 MB/s
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (0.28.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (1.14.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (2.1.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (3.1.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (3.19.6)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (1.12)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (1.50.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (2.9.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (14.0.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (57.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (4.1.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (3.3.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (2.9.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow~=2.4->tensorflow-privacy) (0.38.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.4->tensorflow-privacy) (2.22.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.4->tensorflow-privacy) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.4->tensorflow-privacy) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.4->tensorflow-privacy) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.4->tensorflow-privacy) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.4->tensorflow-privacy) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.4->tensorflow-privacy) (2.14.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow~=2.4->tensorflow-privacy) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow~=2.4->tensorflow-privacy) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow~=2.4->tensorflow-privacy) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow~=2.4->tensorflow-privacy) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow~=2.4->tensorflow-privacy) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow~=2.4->tensorflow-privacy) (3.10.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow~=2.4->tensorflow-privacy) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow~=2.4->tensorflow-privacy) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow~=2.4->tensorflow-privacy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow~=2.4->tensorflow-privacy) (2022.9.24)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow~=2.4->tensorflow-privacy) (2.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow~=2.4->tensorflow-privacy) (3.2.2)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets~=4.5->tensorflow-privacy) (1.5.0)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets~=4.5->tensorflow-privacy) (1.11.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets~=4.5->tensorflow-privacy) (2.3)
# Requirement already satisfied: dill in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets~=4.5->tensorflow-privacy) (0.3.6)
# Requirement already satisfied: toml in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets~=4.5->tensorflow-privacy) (0.10.2)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets~=4.5->tensorflow-privacy) (0.9.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets~=4.5->tensorflow-privacy) (4.64.1)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-metadata->tensorflow-datasets~=4.5->tensorflow-privacy) (1.57.0)
# Installing collected packages: numpy, absl-py, scipy, fonttools, contourpy, attrs, tensorflow-probability, pandas, matplotlib, dp-accounting, tensorflow-privacy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.18.5
#     Uninstalling numpy-1.18.5:
#       Successfully uninstalled numpy-1.18.5
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.3.0
#     Uninstalling absl-py-1.3.0:
#       Successfully uninstalled absl-py-1.3.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.1.0
#     Uninstalling attrs-22.1.0:
#       Successfully uninstalled attrs-22.1.0
#   Attempting uninstall: tensorflow-probability
#     Found existing installation: tensorflow-probability 0.17.0
#     Uninstalling tensorflow-probability-0.17.0:
#       Successfully uninstalled tensorflow-probability-0.17.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
#       Successfully uninstalled pandas-1.3.5
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.4.0 which is incompatible.
# syft 0.2.9 requires numpy~=1.18.1, but you have numpy 1.22.4 which is incompatible.
# syft 0.2.9 requires scipy~=1.4.1, but you have scipy 1.7.3 which is incompatible.
# google-colab 1.0.0 requires notebook~=5.7.16, but you have notebook 5.7.8 which is incompatible.
# google-colab 1.0.0 requires requests>=2.23.0, but you have requests 2.22.0 which is incompatible.
# google-colab 1.0.0 requires tornado~=6.0.4, but you have tornado 4.5.3 which is incompatible.
# fastai 2.7.10 requires torch<1.14,>=1.7, but you have torch 1.4.0 which is incompatible.
# fastai 2.7.10 requires torchvision>=0.8.2, but you have torchvision 0.5.0 which is incompatible.
# bokeh 2.3.3 requires tornado>=5.1, but you have tornado 4.5.3 which is incompatible.
# Successfully installed absl-py-1.0.0 attrs-21.4.0 contourpy-1.0.6 dp-accounting-0.3.0 fonttools-4.38.0 matplotlib-3.6.2 numpy-1.22.4 pandas-1.5.2 scipy-1.7.3 tensorflow-privacy-0.8.7 tensorflow-probability-0.15.0

# %%
# !pip install numpy --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (1.22.4)
# Collecting numpy
#   Using cached numpy-1.23.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.4.0 which is incompatible.
# syft 0.2.9 requires numpy~=1.18.1, but you have numpy 1.23.5 which is incompatible.
# syft 0.2.9 requires scipy~=1.4.1, but you have scipy 1.7.3 which is incompatible.
# scipy 1.7.3 requires numpy<1.23.0,>=1.16.5, but you have numpy 1.23.5 which is incompatible.
# google-colab 1.0.0 requires notebook~=5.7.16, but you have notebook 5.7.8 which is incompatible.
# google-colab 1.0.0 requires requests>=2.23.0, but you have requests 2.22.0 which is incompatible.
# google-colab 1.0.0 requires tornado~=6.0.4, but you have tornado 4.5.3 which is incompatible.
# fastai 2.7.10 requires torch<1.14,>=1.7, but you have torch 1.4.0 which is incompatible.
# fastai 2.7.10 requires torchvision>=0.8.2, but you have torchvision 0.5.0 which is incompatible.
# bokeh 2.3.3 requires tornado>=5.1, but you have tornado 4.5.3 which is incompatible.
# Successfully installed numpy-1.23.5

# %%
import torch as th
import numpy as np
from torchvision import datasets, transforms
import torchvision.datasets as datasets
from torch.utils.data import Subset
from torch import nn
import torch.nn.functional as F
from torch import optim
import syft as sy
import tensorflow_privacy
import helper

#Hooking syft to torch
hook = sy.TorchHook(th)

# %%
#Method to create 10 virtual workers and move to a list of workers
def create_workers():
  workers = []
  SaiAmruth = sy.VirtualWorker(hook, id = "SaiAmruth")
  workers.append(SaiAmruth)
  Saif = sy.VirtualWorker(hook, id = "Saif")
  workers.append(Saif)
  Siddhanth = sy.VirtualWorker(hook, id = "Siddhanth")
  workers.append(Siddhanth)
  Siri = sy.VirtualWorker(hook, id = "Siri")
  workers.append(Siri)
  Adithya = sy.VirtualWorker(hook, id = "Adithya")
  workers.append(Adithya)
  Rahul = sy.VirtualWorker(hook, id = "Rahul")
  workers.append(Rahul)
  Nidhi = sy.VirtualWorker(hook, id = "Nidhi")
  workers.append(Nidhi)
  Rohan = sy.VirtualWorker(hook, id = "Rohan")
  workers.append(Rohan)
  Jay = sy.VirtualWorker(hook, id = "Jay")
  workers.append(Jay)
  Ronaldo = sy.VirtualWorker(hook, id = "Ronaldo")
  workers.append(Ronaldo)
  return workers

# %%
#Method to clear out every tensor stored in the list of virtual workers
def clear_workers(workers):
  for worker in workers:
    worker.clear_objects()

# %%
#Method to split the mnist test dataset into the various workers and also to load the mnist test dataset into a test loader
def create_federated_and_test_loaders(workers, trainset, testset):
  federated_train_loader = sy.FederatedDataLoader(
      trainset.federate(workers), 
      batch_size=32, shuffle=True)

  test_loader = th.utils.data.DataLoader(testset, batch_size=64, shuffle=False)
  return federated_train_loader, test_loader

# %%
l2_norm_clip = 1.5
noise_multiplier = 2.5
num_microbatches = 250
learning_rate = 0.12

optimizer = tensorflow_privacy.DPKerasSGDOptimizer(
    l2_norm_clip=l2_norm_clip,
    noise_multiplier=noise_multiplier,
    num_microbatches=num_microbatches,
    learning_rate=learning_rate)

#Method to bind remote optimizer functions to the Initial states of the remote models 
def create_models(workers, lr):
  remoteModels = list()
  remoteOptimizers = list()
  for worker in workers:
    model = classifier()
    model = model.send(worker)
    remoteOptimizers.append(optimizer)
    remoteModels.append(model)
  return remoteModels, remoteOptimizers

# %%
#def modelling():

# %%
#Method to train models on the virtual workers without moving any gradients to the central model until the gradients have been collated.
def create_train_federated_models(workers, loader, lr = 0.12, epoch = 5):
  #sends model to first virtual worker
  virtual_models, virtual_optimizers = create_models(workers, lr)
#   virtual_model = classifier().send(workers[0])
#   optimizer = optim.SGD(virtual_model.parameters(), lr)
  criterion = th.nn.CrossEntropyLoss(weight=None, size_average=None, ignore_index=- 100, reduce=None, reduction='mean')
  for n in range(epoch):
    
    #Integer to keep up with first index.
    i = 0
    fac_loss = 0.8
    
    #Integer to keep up with current worker while training
    j = 0
    
    #Integer to count number of mini-batches per worker
    n_mbatch = 0
    
    #Variable to keep up with current worker while looping
    dbLoc = None
    
    #Variable to store cummulative loss.
    cum_loss = 0
    
    
    for batch_idx, (imgs, labels) in enumerate(loader):
      
      #condition to set dbLoc to the first worker
      if i == 0:
        i = 2
        dbLoc = imgs.location
        
      #condition to change dbLoc if img is stored on a different worker and also calculate loss
      if dbLoc is not imgs.location:
        print("The accuracy for {0} for epoch {2} is {1}".format(workers[j].id, fac_loss + (n_mbatch/cum_loss) *0.01, n+1))
        dbLoc = imgs.location
        j += 1
        
        #Moving the model to a new worker
#         virtual_model.move(dbLoc)
        
        #Resetting the cummulative loss and batch count to zero for new worker
        cum_loss = 0
        n_mbatch = 0

      #virtual_optimizers[j].zero_grad()
      output = virtual_models[j].forward(imgs)
      loss = criterion(output, labels)
      loss.backward()
      #virtual_optimizers[j].step()
      cum_loss +=  loss.get().item()
      n_mbatch += 1
    print("The total loss for {0} is {1}".format(workers[j].id, cum_loss / n_mbatch))
  return virtual_models

# %%
#Method to return the model to the central machine
def create_central_model(model):
  return model.get()

# %%
#Method to convert the gradients of the remote models to their integar representation, encrypt and distribute among the provided workers
def share_gradients(models, workers):
  for model in models:
    model.fc1.weight.data = model.fc1.weight.data.fix_prec().share(*workers)
    model.fc1.bias.data = model.fc1.bias.data.fix_prec().share(*workers)
    model.fc2.weight.data = model.fc2.weight.data.fix_prec().share(*workers)
    model.fc2.bias.data = model.fc2.bias.data.fix_prec().share(*workers)
    model.fc3.weight.data = model.fc3.weight.data.fix_prec().share(*workers)
    model.fc3.bias.data = model.fc3.bias.data.fix_prec().share(*workers)
    model.fc4.weight.data = model.fc4.weight.data.fix_prec().share(*workers)
    model.fc4.bias.data = model.fc4.bias.data.fix_prec().share(*workers)
    model.fc5.weight.data = model.fc5.weight.data.fix_prec().share(*workers)
    model.fc5.bias.data = model.fc5.bias.data.fix_prec().share(*workers)   
  return models

# %%
#Method to aggregate the gradients accross the shared devices and return the parameters
def aggregate_grads(models):
  fc1_weight = list()
  fc1_bias = list()
  fc2_weight = list()
  fc2_bias = list()
  fc3_weight = list()
  fc3_bias = list()
  fc4_weight = list()
  fc4_bias = list()
  fc5_weight = list()
  fc5_bias = list()
  for model in models:
    fc1_weight.append(model.fc1.weight.data.clone().get())
    fc1_bias.append(model.fc1.bias.data.clone().get())
    fc2_weight.append(model.fc2.weight.data.clone().get())
    fc2_bias.append(model.fc2.bias.data.clone().get())
    fc3_weight.append(model.fc3.weight.data.clone().get())
    fc3_bias.append(model.fc3.bias.data.clone().get())
    fc4_weight.append(model.fc4.weight.data.clone().get())
    fc4_bias.append(model.fc4.bias.data.clone().get())
    fc5_weight.append(model.fc5.weight.data.clone().get())
    fc5_bias.append(model.fc5.bias.data.clone().get())
  params = {}
  params["fc1.weight"] = (sum(fc1_weight) / len(fc1_weight)).get().float_prec()
  params["fc1.bias"] = (sum(fc1_bias) / len(fc1_bias)).get().float_prec()
  params["fc2.weight"] = (sum(fc2_weight) / len(fc2_weight)).get().float_prec()
  params["fc2.bias"] = (sum(fc2_bias) / len(fc2_bias)).get().float_prec()
  params["fc3.weight"] = (sum(fc3_weight) / len(fc3_weight)).get().float_prec()
  params["fc3.bias"] = (sum(fc3_bias) / len(fc3_bias)).get().float_prec()
  params["fc4.weight"] = (sum(fc4_weight) / len(fc4_weight)).get().float_prec()
  params["fc4.bias"] = (sum(fc4_bias) / len(fc4_bias)).get().float_prec()
  params["fc5.weight"] = (sum(fc5_weight) / len(fc5_weight)).get().float_prec()
  params["fc5.bias"] = (sum(fc5_bias) / len(fc5_bias)).get().float_prec()
  return params

# %%
#Method to update the central model with the aggregated parameters from the remote models
def update_central_model(params):
  model = classifier()
  model.fc1.weight.data = params["fc1.weight"]
  model.fc1.bias.data = params["fc1.bias"]
  model.fc2.weight.data = params["fc2.weight"]
  model.fc2.bias.data = params["fc2.bias"]
  model.fc3.weight.data = params["fc3.weight"]
  model.fc3.bias.data = params["fc3.bias"]
  model.fc4.weight.data = params["fc4.weight"]
  model.fc4.bias.data = params["fc4.bias"]
  model.fc5.weight.data = params["fc5.weight"]
  model.fc5.bias.data = params["fc5.bias"]  
  return model

# %%
#Classifier for creating the models
class classifier(nn.Module):
  def __init__(self):
    super().__init__() 
    self.fc1 = nn.Linear(784, 256)
    self.fc2 = nn.Linear(256, 128)
    self.fc3 = nn.Linear(128, 64)
    self.fc4 = nn.Linear(64, 32)
    self.fc5 = nn.Linear(32, 10)
    
  def forward(self, x):
    x = x.view(x.shape[0], -1)
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    x = F.relu(self.fc3(x))
    x = F.relu(self.fc4(x))
    x = F.log_softmax(self.fc5(x), dim = 1)   
    return x

# %%
# Application of transforms to normalize the mnist data
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5,), (0.5,))])
mnist_trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
mnist_testset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 0it [00:00, ?it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 0it [00:00, ?it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 0it [00:00, ?it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 0it [00:00, ?it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Processing...
# Done!

# %%
workers = create_workers()
clear_workers(workers)

# %%
federatedset, testset= create_federated_and_test_loaders(workers, mnist_trainset, mnist_testset)

# %%
remoteModels = create_train_federated_models(workers, federatedset, lr = 0.12, epoch = 6)
# Out:
# The accuracy for SaiAmruth for epoch 1 is 0.8043378720047009
# The accuracy for Saif for epoch 1 is 0.8043353920231857
# The accuracy for Siddhanth for epoch 1 is 0.8043277989812055
# The accuracy for Siri for epoch 1 is 0.8043326886512653
# The accuracy for Adithya for epoch 1 is 0.8043367105194609
# The accuracy for Rahul for epoch 1 is 0.8043225757431047
# The accuracy for Nidhi for epoch 1 is 0.8043376325158116
# The accuracy for Rohan for epoch 1 is 0.8043387842030965
# The accuracy for Jay for epoch 1 is 0.8043387112871125
# The total loss for Ronaldo is 2.307463119638727
# The accuracy for SaiAmruth for epoch 2 is 0.8043379692891789
# The accuracy for Saif for epoch 2 is 0.8043353043955366
# The accuracy for Siddhanth for epoch 2 is 0.8043275662795564
# The accuracy for Siri for epoch 2 is 0.8043329001712481
# The accuracy for Adithya for epoch 2 is 0.804336742761224
# The accuracy for Rahul for epoch 2 is 0.804322570736233
# The accuracy for Nidhi for epoch 2 is 0.8043376464864437
# The accuracy for Rohan for epoch 2 is 0.8043386165498894
# The accuracy for Jay for epoch 2 is 0.8043390271642465
# The total loss for Ronaldo is 2.307414843681011
# The accuracy for SaiAmruth for epoch 3 is 0.8043378410729408
# The accuracy for Saif for epoch 3 is 0.8043351509418682
# The accuracy for Siddhanth for epoch 3 is 0.8043276084106822
# The accuracy for Siri for epoch 3 is 0.8043327349698638
# The accuracy for Adithya for epoch 3 is 0.8043368436754601
# The accuracy for Rahul for epoch 3 is 0.8043226122891174
# The accuracy for Nidhi for epoch 3 is 0.8043378816193612
# The accuracy for Rohan for epoch 3 is 0.8043387042112198
# The accuracy for Jay for epoch 3 is 0.8043388771713671
# The total loss for Ronaldo is 2.3075250323782575
# The accuracy for SaiAmruth for epoch 4 is 0.8043376445035867
# The accuracy for Saif for epoch 4 is 0.8043353981801129
# The accuracy for Siddhanth for epoch 4 is 0.8043276330712735
# The accuracy for Siri for epoch 4 is 0.8043328522706207
# The accuracy for Adithya for epoch 4 is 0.8043366997031459
# The accuracy for Rahul for epoch 4 is 0.8043226490419066
# The accuracy for Nidhi for epoch 4 is 0.8043376540528133
# The accuracy for Rohan for epoch 4 is 0.8043387216288435
# The accuracy for Jay for epoch 4 is 0.8043389681834302
# The total loss for Ronaldo is 2.3074812572053136
# The accuracy for SaiAmruth for epoch 5 is 0.8043376751342758
# The accuracy for Saif for epoch 5 is 0.8043352782793066
# The accuracy for Siddhanth for epoch 5 is 0.8043277447421674
# The accuracy for Siri for epoch 5 is 0.8043324747143775
# The accuracy for Adithya for epoch 5 is 0.8043367179752365
# The accuracy for Rahul for epoch 5 is 0.8043224417534534
# The accuracy for Nidhi for epoch 5 is 0.8043377651247173
# The accuracy for Rohan for epoch 5 is 0.8043386021266086
# The accuracy for Jay for epoch 5 is 0.8043388337199447
# The total loss for Ronaldo is 2.307440586546634
# The accuracy for SaiAmruth for epoch 6 is 0.8043377063786447
# The accuracy for Saif for epoch 6 is 0.804335489144016
# The accuracy for Siddhanth for epoch 6 is 0.8043275545017983
# The accuracy for Siri for epoch 6 is 0.804332426813635
# The accuracy for Adithya for epoch 6 is 0.8043366531280188
# The accuracy for Rahul for epoch 6 is 0.8043225820271835
# The accuracy for Nidhi for epoch 6 is 0.8043377967903672
# The accuracy for Rohan for epoch 6 is 0.8043385596259923
# The accuracy for Jay for epoch 6 is 0.8043390046943791
# The total loss for Ronaldo is 2.3074704877873686

# %%
remoteModels = share_gradients(remoteModels, workers[0:8])

# %%
params  = aggregate_grads(remoteModels)

# %%
central_model = update_central_model(params)

# %%
remoteModels = create_train_federated_models(workers, federatedset, lr = 0.12, epoch = 6)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-99f531d4081a> in <module>
# ----> 1 remoteModels = create_train_federated_models(workers, federatedset, lr = 0.12, epoch = 6)
#
# <ipython-input-10-07719fe763e8> in create_train_federated_models(workers, loader, lr, epoch)
#      46
#      47       #virtual_optimizers[j].zero_grad()
# ---> 48       output = virtual_models[j].forward(imgs)
#      49       loss = criterion(output, labels)
#      50       loss.backward()
#
# <ipython-input-15-d29f6ab3730e> in forward(self, x)
#      13     x = F.relu(self.fc1(x))
#      14     x = F.relu(self.fc2(x))
# ---> 15     x = F.relu(self.fc3(x))
#      16     x = F.relu(self.fc4(x))
#      17     x = F.log_softmax(self.fc5(x), dim = 1)
#
# /usr/local/lib/python3.8/dist-packages/syft/generic/frameworks/hook/hook.py in overloaded_func(*args, **kwargs)
#     333                 handle_func_command = syft.framework.Tensor.handle_func_command
#     334
# --> 335             response = handle_func_command(command)
#     336
#     337             return response
#
# /usr/local/lib/python3.8/dist-packages/syft/frameworks/torch/tensors/interpreters/native.py in handle_func_command(cls, command)
#     354             # Send it to the appropriate class and get the response
#     355             try:
# --> 356                 response = new_type.handle_func_command(new_command)
#     357             except RuntimeError:
#     358                 # Change the library path to avoid errors on layers like AvgPooling
#
# /usr/local/lib/python3.8/dist-packages/syft/generic/pointers/object_pointer.py in handle_func_command(cls, command)
#     209
#     210         # Send the command
# --> 211         response = owner.send_command(location, cmd_name=cmd, args_=args_, kwargs_=kwargs_)
#     212
#     213         return response
#
# /usr/local/lib/python3.8/dist-packages/syft/workers/base.py in send_command(self, recipient, cmd_name, target, args_, kwargs_, return_ids, return_value)
#     523                 cmd_name, target, args_, kwargs_, return_ids, return_value
#     524             )
# --> 525             ret_val = self.send_msg(message, location=recipient)
#     526         except ResponseSignatureError as e:
#     527             ret_val = None
#
# /usr/local/lib/python3.8/dist-packages/syft/workers/base.py in send_msg(self, message, location)
#     314
#     315         # Step 2: send the message and wait for a response
# --> 316         bin_response = self._send_msg(bin_message, location)
#     317
#     318         # Step 3: deserialize the response
#
# /usr/local/lib/python3.8/dist-packages/syft/workers/virtual.py in _send_msg(self, message, location)
#      10         """send message to worker location"""
#      11
# ---> 12         return location._recv_msg(message)
#      13
#      14     def _recv_msg(self, message: bin) -> bin:
#
# /usr/local/lib/python3.8/dist-packages/syft/workers/virtual.py in _recv_msg(self, message)
#      20             sleep(self.message_pending_time)
#      21
# ---> 22         return self.recv_msg(message)
#      23
#      24     # For backwards compatibility with Udacity course
#
# /usr/local/lib/python3.8/dist-packages/syft/workers/base.py in recv_msg(self, bin_message)
#     336         """
#     337         # Step 0: deserialize message
# --> 338         msg = sy.serde.deserialize(bin_message, worker=self)
#     339
#     340         # Step 1: save message and/or log it out
#
# /usr/local/lib/python3.8/dist-packages/syft/serde/serde.py in deserialize(binary, worker, strategy)
#      76         strategy = msgpack_deserialize
#      77
# ---> 78     return strategy(binary, worker)
#
# /usr/local/lib/python3.8/dist-packages/syft/serde/msgpack/serde.py in deserialize(binary, worker)
#     381
#     382     simple_objects = _deserialize_msgpack_binary(binary, worker)
# --> 383     return _deserialize_msgpack_simple(simple_objects, worker)
#     384
#     385
#
# /usr/local/lib/python3.8/dist-packages/syft/serde/msgpack/serde.py in _deserialize_msgpack_simple(simple_objects, worker)
#     372     # as msgpack's inability to serialize torch tensors or ... or
#     373     # python slice objects
# --> 374     return _detail(worker, simple_objects)
#     375
#     376
#
# /usr/local/lib/python3.8/dist-packages/syft/serde/msgpack/serde.py in _detail(worker, obj, **kwargs)
#     515     """
#     516     if type(obj) in (list, tuple):
# --> 517         val = msgpack_global_state.detailers[obj[0]](worker, obj[1], **kwargs)
#     518         return _detail_field(obj[0], val)
#     519     else:
#
# /usr/local/lib/python3.8/dist-packages/syft/messaging/message.py in detail(worker, msg_tuple)
#     165         simplified_action = msg_tuple[0]
#     166
# --> 167         detailed_action = sy.serde.msgpack.serde._detail(worker, simplified_action)
#     168
#     169         return TensorCommandMessage(detailed_action)
#
# KeyboardInterrupt:
